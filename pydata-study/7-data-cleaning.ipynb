# %%
import numpy as np
import pandas as pd

# %%
# 创建随机数生成器
rng = np.random.default_rng(seed=1234)

# %% [markdown]
# # 7.1 处理缺失值，哨兵值

# %%
float_data = pd.Series([1.2, -3.5, np.nan, 0])

float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data = pd.Series(['aardvark', np.nan, None, 'avocado'])

string_data
# Out:
# 0    aardvark
# 1         NaN
# 2        None
# 3     avocado
# dtype: object

# %%
string_data.isna()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
float_data = pd.DataFrame(rng.standard_normal((3,3)), 
                          dtype='float64', 
                          columns=['a', 'b', 'c'])

float_data
# Out:
#           a         b         c
# 0 -1.603837  0.064100  0.740891
# 1  0.152619  0.863744  2.913099
# 2 -1.478823  0.945473 -1.666135

# %%
float_data.iloc[:2, 2] = np.nan
float_data.isna()
# Out:
#        a      b      c
# 0  False  False   True
# 1  False  False   True
# 2  False  False  False

# %%
float_data.loc[[0,2] , ['a', 'b']] = np.nan # loc() 根据标签索引
float_data.isna()
# Out:
#        a      b      c
# 0   True   True   True
# 1  False  False   True
# 2   True   True  False

# %% [markdown]
# ## 过滤缺失值

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])

data.dropna() # 过滤缺失值
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notna()] # =data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
dataf = pd.DataFrame(rng.standard_normal((4,3)))
dataf.iloc[1:3, 1:] = np.nan
dataf.iloc[2:, 0] =np.nan
dataf
# Out:
#           0         1         2
# 0  0.343745 -0.512444  1.323759
# 1 -0.860280       NaN       NaN
# 2       NaN       NaN       NaN
# 3       NaN -1.002166  0.268346

# %%
dataf.dropna()
# Out:
#           0         1         2
# 0  0.343745 -0.512444  1.323759

# %%
dataf.dropna(how='all')
#    - `'any'` (默认)："零容忍"策略 - 确保每个保留的观测都是完整的
#   - `'all'`："最大限度保留"策略 - 只删除完全没有信息的行/列
# Out:
#           0         1         2
# 0  0.343745 -0.512444  1.323759
# 1 -0.860280       NaN       NaN
# 3       NaN -1.002166  0.268346

# %%
dataf[4] = np.nan
dataf
# Out:
#           0         1         2   4
# 0  0.343745 -0.512444  1.323759 NaN
# 1 -0.860280       NaN       NaN NaN
# 2       NaN       NaN       NaN NaN
# 3       NaN -1.002166  0.268346 NaN

# %%
dataf.dropna(axis='columns', how='all')
# Out:
#           0         1         2
# 0  0.343745 -0.512444  1.323759
# 1 -0.860280       NaN       NaN
# 2       NaN       NaN       NaN
# 3       NaN -1.002166  0.268346

# %%
df = pd.DataFrame(rng.standard_normal((7, 3)))
df.iloc[:4, 1] = np.nan
df.iloc[:2, 2] = np.nan

df
# Out:
#           0         1         2
# 0 -0.163806       NaN       NaN
# 1 -1.174150       NaN       NaN
# 2 -0.136644       NaN -0.088218
# 3  1.557242       NaN  0.522726
# 4  0.937150 -0.836909  0.098068
# 5 -1.570553 -1.779878  0.918836
# 6 -0.149068  1.005636  0.131018

# %%
df.dropna()
# Out:
#           0         1         2
# 4  0.937150 -0.836909  0.098068
# 5 -1.570553 -1.779878  0.918836
# 6 -0.149068  1.005636  0.131018

# %%
df.dropna(thresh=2) # threshold = 2 设置一个阈值
# Out:
#           0         1         2
# 2 -0.136644       NaN -0.088218
# 3  1.557242       NaN  0.522726
# 4  0.937150 -0.836909  0.098068
# 5 -1.570553 -1.779878  0.918836
# 6 -0.149068  1.005636  0.131018

# %% [markdown]
# ## 补充缺失值

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0 -0.163806  0.000000  0.000000
# 1 -1.174150  0.000000  0.000000
# 2 -0.136644  0.000000 -0.088218
# 3  1.557242  0.000000  0.522726
# 4  0.937150 -0.836909  0.098068
# 5 -1.570553 -1.779878  0.918836
# 6 -0.149068  1.005636  0.131018

# %% [markdown]
# 用字典调用 `fillna` 时，你可以为每列使用不同的填充值：

# %%
df.fillna({1: 0.5, 2: 0})
# Out:
#           0         1         2
# 0 -0.163806  0.500000  0.000000
# 1 -1.174150  0.500000  0.000000
# 2 -0.136644  0.500000 -0.088218
# 3  1.557242  0.500000  0.522726
# 4  0.937150 -0.836909  0.098068
# 5 -1.570553 -1.779878  0.918836
# 6 -0.149068  1.005636  0.131018

# %% [markdown]
# 用于`.reindex()`的插值方法（见表 5.3）也可以用于 `fillna`：

# %%
df = pd.DataFrame(rng.standard_normal((6,3)))
df.iloc[2:, 1] = np.nan
df.iloc[4:, 2] = np.nan

df
# Out:
#           0         1         2
# 0 -0.773047  2.894307  1.377078
# 1  0.171456  0.022242  1.652686
# 2 -0.321875       NaN  0.654605
# 3 -1.321826       NaN  1.117381
# 4  0.546459       NaN       NaN
# 5 -0.491283       NaN       NaN

# %%
df.fillna(method='ffill') # 将过时
# Out:
# /var/folders/1m/2jsf455s4r7dx9t8l233n55c0000gp/T/ipykernel_5759/1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#           0         1         2
# 0 -0.773047  2.894307  1.377078
# 1  0.171456  0.022242  1.652686
# 2 -0.321875  0.022242  0.654605
# 3 -1.321826  0.022242  1.117381
# 4  0.546459  0.022242  1.117381
# 5 -0.491283  0.022242  1.117381

# %%
df.ffill()
# Out:
#           0         1         2
# 0 -0.773047  2.894307  1.377078
# 1  0.171456  0.022242  1.652686
# 2 -0.321875  0.022242  0.654605
# 3 -1.321826  0.022242  1.117381
# 4  0.546459  0.022242  1.117381
# 5 -0.491283  0.022242  1.117381

# %%
df.ffill(limit=1) # 填充数 = limit value
# Out:
#           0         1         2
# 0 -0.773047  2.894307  1.377078
# 1  0.171456  0.022242  1.652686
# 2 -0.321875  0.022242  0.654605
# 3 -1.321826       NaN  1.117381
# 4  0.546459       NaN  1.117381
# 5 -0.491283       NaN       NaN

# %%
print('dataframe 切片成 Series：')
print(df.median())
print(df.median().shape)
print('-------')
print('Series 按广播机制默认匹配 dataframe 的 colums => col1 = 1.458275， col2 = 1.247230')
print(df.fillna(df.median())) # 默认 axis =0
# Out:
# dataframe 切片成 Series：
# 0   -0.406579
# 1    1.458275
# 2    1.247230
# dtype: float64
# (3,)
# -------
# Series 按广播机制默认匹配 dataframe 的 colums => col1 = 1.458275， col2 = 1.247230
#           0         1         2
# 0 -0.773047  2.894307  1.377078
# 1  0.171456  0.022242  1.652686
# 2 -0.321875  1.458275  0.654605
# 3 -1.321826  1.458275  1.117381
# 4  0.546459  1.458275  1.247230
# 5 -0.491283  1.458275  1.247230

# %%
print(df.median(axis=1))
print(df.median(axis=1).shape) # 压缩掉了 axis=1，剩下 shape （6， ）
print('-------')
print(df.fillna(df.median(axis=1), axis=0)) # 默认 axis=0 对齐，fillna 暂不支持 axis >0 高维运算
# Out:
# 0    1.377078
# 1    0.171456
# 2    0.166365
# 3   -0.102223
# 4    0.546459
# 5   -0.491283
# dtype: float64
# (6,)
# -------
#           0         1         2
# 0 -0.773047  2.894307  1.377078
# 1  0.171456  0.022242  1.652686
# 2 -0.321875  0.171456  0.654605
# 3 -1.321826  0.171456  1.117381
# 4  0.546459  0.171456  0.166365
# 5 -0.491283  0.171456  0.166365

# %% [markdown]
# # 数据转换 data transformation

# %% [markdown]
# ## 删除重复内容

# %%
data = pd.DataFrame({'k1': ['one', 'two']*3+['two'],
                     'k2': [1, 1, 2, 3, 3, 4, 4]})

data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated() 
# 因为row 5, 6 的 k1, k2 列相同
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data['v1'] = range(7)
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates(subset=['k1']) # 默认保留第一个观察到的值组合
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
data.drop_duplicates(subset=['k1'], keep='last') # keep="last" will return the last one
# Out:
#     k1  k2  v1
# 4  one   3   4
# 6  two   4   6

# %%
data.drop_duplicates(subset=['k1', 'k2'])
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5

# %% [markdown]
# ## 使用函数或映射mapping转换数据
